# %%
import pandas as pd
data_frame = pd.read_csv('worldometer_data.csv')
data_frame.shape
# Out:
# (209, 16)

# %%
data_frame.describe()
# Out:
#          Population    TotalCases     NewCases    TotalDeaths   NewDeaths  \
# count  2.080000e+02  2.090000e+02    25.000000     185.000000   15.000000
# mean   3.040565e+07  7.927600e+04   665.360000    3524.589189   40.066667
# std    1.047374e+08  3.718449e+05  1158.075159   14312.174186   86.374158
# min    8.010000e+02  1.000000e+01     1.000000       1.000000    1.000000
# 25%    9.659750e+05  5.090000e+02     8.000000      22.000000    1.000000
# 50%    7.041486e+06  3.297000e+03   239.000000     103.000000    8.000000
# 75%    2.574560e+07  3.362400e+04   473.000000     720.000000   39.000000
# max    1.380975e+09  4.433410e+06  4973.000000  150444.000000  342.000000
#
#        TotalRecovered  NewRecovered   ActiveCases  Serious,Critical  \
# count    2.050000e+02     20.000000  2.050000e+02        127.000000
# mean     4.857829e+04    842.450000  2.578342e+04        524.015748
# std      2.084603e+05   1559.143472  1.618815e+05       2064.263226
# ...

# %%
data_frame.values
# Out:
# array([['USA', 'North America', 331145197.0, ..., 55018236.0, 166145.0,
#         'Americas'],
#        ['Brazil', 'South America', 212669472.0, ..., 12601096.0, 59252.0,
#         'Americas'],
#        ['India', 'Asia', 1380974594.0, ..., 17334885.0, 12553.0,
#         'South-EastAsia'],
#        ...,
#        ['Vatican City', 'Europe', 801.0, ..., nan, nan, 'Europe'],
#        ['Caribbean Netherlands', 'North America', 26240.0, ..., 424.0,
#         16159.0, nan],
#        ['Western Sahara', 'Africa', 598280.0, ..., nan, nan, 'Africa']],
#       dtype=object)

# %%
data_frame.loc[20:30]
# Out:
#    Country/Region      Continent   Population  TotalCases  NewCases  \
# 20         Canada  North America   37765990.0      114597       NaN
# 21           Iraq           Asia   40281305.0      112585       NaN
# 22          Qatar           Asia    2807805.0      109597       NaN
# 23      Indonesia           Asia  273729387.0      100303       NaN
# 24          Egypt         Africa  102463710.0       92482       NaN
# 25     Kazakhstan           Asia   18792532.0       84648    1526.0
# 26    Philippines           Asia  109682866.0       82040       NaN
# 27        Ecuador  South America   17661500.0       81161       NaN
# 28         Sweden         Europe   10103878.0       79395       NaN
# 29           Oman           Asia    5114887.0       77058       NaN
# 30        Bolivia  South America   11684107.0       71181    1752.0
#
#     TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 20       8901.0        NaN         99860.0           NaN       5836.0
# ...

# %%
data_frame[data_frame["Continent"]=="Asia"] # with .head() will only show first five items
# Out:
#     Country/Region Continent    Population  TotalCases  NewCases  TotalDeaths  \
# 2            India      Asia  1.380975e+09     1484136    1633.0      33461.0
# 10            Iran      Asia  8.406825e+07      293606       NaN      15912.0
# 11        Pakistan      Asia  2.211785e+08      275225     936.0       5865.0
# 12    Saudi Arabia      Asia  3.485110e+07      268934       NaN       2760.0
# 15          Turkey      Asia  8.440355e+07      227019       NaN       5630.0
# 16      Bangladesh      Asia  1.648066e+08      226225       NaN       2965.0
# 21            Iraq      Asia  4.028130e+07      112585       NaN       4458.0
# 22           Qatar      Asia  2.807805e+06      109597       NaN        165.0
# 23       Indonesia      Asia  2.737294e+08      100303       NaN       4838.0
# 25      Kazakhstan      Asia  1.879253e+07       84648    1526.0        585.0
# 26     Philippines      Asia  1.096829e+08       82040       NaN       1945.0
# ...

# %%
data_frame["TotalCases"].hist()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>
